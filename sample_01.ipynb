# %%
import pandas as pd

df = pd.read_csv("sample_1pml_1570512675146.csv")
df.head()
# Out:
#    CanDispatch CarImage  CompanyID  Direction DisplayName  DriverNumber  \
# 0        False   yellow          1        248         普通車        167007
# 1        False    black          1         59         黒タク         40634
# 2        False    black          1         88         黒タク         40634
# 3        False   yellow          1        339         普通車        115905
# 4        False    black          1        101         黒タク         40634
#
#     Latitude   Longitude  RadioNumber  SpeedFrom  SpeedTo  \
# 0  35.690970  139.754970         4285         75     75.0
# 1  35.684328  139.785427          454         55     55.0
# 2  35.695951  139.756240         1544         41     41.0
# 3  35.673969  139.723400         3355         54     54.0
# 4  35.694710  139.785870         1544         47     47.0
#
#             StatusTime VehicleStatus
# 0  2016-06-28 20:43:20            実車
# 1  2016-10-19 03:31:41            実車
# 2  2016-06-03 11:19:25            実車
# ...
